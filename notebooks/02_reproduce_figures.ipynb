# %% [markdown]
# # 02. Reproduce Figures — Journal-Quality Plot Generation
#
# This notebook calls the reproduction script to compile all 7 figures in the paper, saving them in the `results/figures/` directory, and shows how you can load and display them inside Jupyter.

# %%
import sys
import os

# Add scripts to path
sys.path.append('../')

# Import and execute figure generation
from scripts import reproduce_figures

print("Generating all figures...")
reproduce_figures.main()

# %% [markdown]
# ### Display Figure 3: Random Forest Feature Importance

# %%
from PIL import Image
import matplotlib.pyplot as plt

fig3 = Image.open('results/figures/fig3_feature_importance.png')
plt.figure(figsize=(10, 8))
plt.imshow(fig3)
plt.axis('off')
plt.title('Figure 3: Feature Importance', fontsize=14)
plt.show()

# %% [markdown]
# ### Display Figure 4: Temporal Routing Lag

# %%
fig4 = Image.open('results/figures/fig4_routing_lag.png')
plt.figure(figsize=(10, 8))
plt.imshow(fig4)
plt.axis('off')
plt.title('Figure 4: Temporal Routing Lag', fontsize=14)
plt.show()
